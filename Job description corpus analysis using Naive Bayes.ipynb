# %% [markdown]
# ## Analyzing job description corpus using Naive Bayes

# %% [markdown]
# # Part A (basic text mining)

# %% [markdown]
# A1. What are the top 5 parts of speech in this corpus of job descriptions? How frequently do they appear?

# %% [markdown]
# Solution:

# %% [markdown]
# Reading the training data and selecting random 10,000 data points.

# %%
import pandas as pd
from nltk.corpus import brown
import nltk

desc = pd.read_csv('Train_rev1.csv', dtype= 'unicode')
rev_data = desc.sample(random_state = 100,n=10000)

# %% [markdown]
# Tokenizing each row in the column 'FullDescription' and couting parts of speech

# %%
from collections import Counter
def poscount(s):
    return Counter([j for i,j in nltk.pos_tag(nltk.word_tokenize(s))])

rev_data['tt']=rev_data['FullDescription'].apply(poscount)

# %% [markdown]
# Accumulating all the counts from every row into a single dictionary

# %%
result={}
def accumulate(dict):
    for key, value in dict.items():
        if key in result.keys():
            result[key] +=value
        else:
            result[key] = value

rev_data['tt'].map(accumulate)
result
# Out:
# {'$': 212,
#  "''": 342,
#  '(': 9508,
#  ')': 9779,
#  ',': 95655,
#  '.': 91103,
#  ':': 22473,
#  'CC': 128478,
#  'CD': 17716,
#  'DT': 203554,
#  'EX': 1041,
#  'FW': 1286,
#  'IN': 262161,
#  'JJ': 219119,
#  'JJR': 3179,
#  'JJS': 4534,
#  'MD': 41145,
#  'NN': 462903,
#  'NNP': 347999,
#  'NNPS': 5633,
#  'NNS': 179319,
#  'PDT': 476,
#  'POS': 3142,
#  'PRP': 49296,
#  'PRP$': 30398,
#  'RB': 57829,
#  'RBR': 929,
#  'RBS': 854,
#  'RP': 3589,
#  'TO': 82660,
#  'UH': 72,
#  'VB': 129105,
#  'VBD': 12370,
#  'VBG': 84236,
#  'VBN': 47459,
#  'VBP': 46417,
#  'VBZ': 41501,
#  'WDT': 5722,
#  'WP': 5806,
#  'WP$': 84,
#  'WRB': 3471,
#  '``': 16}

# %% [markdown]
# Selecting the 5 most common parts of speech based on frequency

# %%
from operator import itemgetter
sorted(result.items(), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('NN', 462903),
#  ('NNP', 347999),
#  ('IN', 262161),
#  ('JJ', 219119),
#  ('DT', 203554)]

# %% [markdown]
# Answer A1) The top 5 parts of speech are
# Common noun
# Proper noun
# Preposition or conjuction
# Adjective
# Determiner

# %% [markdown]
# A2. Does this corpus support Zipf’s law? Plot the most common 100 words in the corpus against the theoretical prediction of the law. For this question, do not remove stopwords. Also do not perform stemming or lemmatization.

# %% [markdown]
# Solution:
# Counting the frequency of each word in every row. Without removing stopwords or lemmatizing

# %%
from collections import Counter
def wordcount(s):
    return Counter([i for i in nltk.word_tokenize(s)])

rev_data['wt']=rev_data['FullDescription'].apply(wordcount)
rev_data['wt']
# Out:
# 190731    {'A': 2, 'Marketing': 2, 'Executive': 1, 'is':...
# 88950     {'The': 4, 'Senior': 1, 'Analyst': 2, 'is': 3,...
# 51163     {'Lead': 6, 'Java': 4, 'Developer': 6, 'Front'...
# 155224    {'Fixed': 1, 'term': 1, 'for': 1, '12': 1, 'mo...
# 61106     {'We': 1, 'are': 3, 'currently': 1, 'recruitin...
# 607       {'Just': 2, 'Social': 4, 'Care': 3, 'are': 2, ...
# 45539     {'Graduate': 2, 'Developer': 2, 'Software': 1,...
# 118084    {'My': 1, 'client': 3, 'are': 1, 'currently': ...
# 170393    {'Theatre': 2, 'Technician': 5, '(': 1, 'Costu...
# 71489     {'Compiler': 4, 'Developer': 1, 'London': 1, '...
# 146463    {'Our': 1, 'client': 1, 'a': 4, 'leading': 1, ...
# 137799    {'Convergence/Mobile': 3, 'Working/M2M': 3, 'S...
# 92460     {'UCL': 5, 'Development': 3, 'and': 19, 'Alumn...
# 3073      {'Care': 4, 'Assistants': 2, 'required': 3, 't...
# 28699     {'A': 1, 'successful': 1, 'branch': 1, 'of': 5...
# 89421     {'36': 1, 'hours': 1, 'per': 1, 'week': 1, ','...
# 201109    {'Internal': 3, 'Sales': 7, 'Engineer': 4, 'Lo...
# 45130     {'Our': 1, 'client': 1, 'is': 4, 'a': 7, 'bout...
# 213435    {'The': 5, 'Role': 1, ':': 4, '•Key': 1, 'resp...
# 128982    {'Senior': 2, 'QA': 1, 'Engineers': 2, 'Java':...
# 131916    {'Our': 1, 'client': 1, 'is': 3, 'a': 6, 'glob...
# 51917     {'A': 1, 'major': 1, 'contractor': 1, 'in': 4,...
# 47183     {'Your': 2, 'World': 2, 'Healthcare': 2, 'is':...
# 78463     {'Are': 1, 'you': 4, 'looking': 1, 'for': 2, '...
# 150116    {'Education': 3, 'Teaching': 1, 'Officer': 3, ...
# 6671      {'Senior': 1, 'Software': 4, 'Developer': 4, '...
# 240500    {'Project': 11, 'Management': 1, 'Director': 7...
# 86791     {'FREE': 1, 'REGISTRATION': 1, 'WITH': 1, 'MED...
# 25591     {'Junior': 2, 'HR': 8, 'Business': 2, 'Partner...
# 128636    {'Redrock': 1, 'is': 1, 'currently': 1, 'seeki...
#                                 ...
# 99762     {'Our': 1, 'client': 1, ',': 3, 'part': 1, 'of...
# 183691    {'Design': 3, 'Manager': 2, '(': 1, 'Mechanica...
# 232449    {'Year': 2, '****': 1, 'Primary': 1, 'Teacher'...
# 161844    {'Introduction': 1, 'Our': 1, 'Client': 1, 'ar...
# 68072     {'This': 2, 'is': 1, 'a': 4, 'fantastic': 1, '...
# 29337     {'Clinical': 3, 'Research': 2, 'Fellow': 1, 'f...
# 150804    {'I': 1, 'have': 2, 'a': 6, 'requirement': 1, ...
# 84875     {'I': 1, 'm': 1, ',': 27, 'working': 4, 'on': ...
# 160374    {'Residential': 1, 'Surveyor': 3, 'required': ...
# 164054    {'MedicsPro': 2, 'are': 2, 'acting': 1, 'on': ...
# 113808    {'Job': 1, 'Advert': 1, 'Assistant': 1, 'Super...
# 1711      {'Allied': 2, 'Healthcare': 2, 'is': 5, 'one':...
# 145292    {'Business': 3, 'Development': 2, '(': 1, 'Fie...
# 98929     {'GENERAL': 1, 'MANAGER': 1, 'NANDO`S': 1, 'RE...
# 216281    {'Our': 1, 'fantastic': 1, 'client': 1, 'based...
# 146349    {'Java': 13, 'Developer/Software': 2, 'Enginee...
# 135668    {'Chef': 4, 'de': 3, 'Partie': 4, 'Boutique': ...
# 204750    {'Credit': 2, 'Controller': 2, 'Birmingham': 1...
# 118089    {'Are': 2, 'you': 2, 'an': 11, 'experienced': ...
# 107178    {'Observational': 6, 'Research': 6, 'Manager':...
# 201103    {'Junior': 7, '.Net': 7, 'Developer': 6, '/': ...
# 39493     {'Computer': 2, 'People': 2, 'are': 2, 'curren...
# 65439     {'FM': 9, 'Sourcing': 7, 'Manager': 2, 'Facili...
# 2333      {'Location': 1, ':': 5, 'Devon': 1, '(': 2, 'v...
# 232665    {'Possession': 3, 'Planner': 3, 'Rail': 4, 'Ci...
# 72706     {'Membership': 1, 'Development': 1, 'Assistant...
# 161477    {'Chef': 1, 'needed': 1, 'for': 5, 'restaurant...
# 779       {'Job': 2, 'Ref': 1, 'VAC****': 1, 'Title': 1,...
# 192496    {'Word': 1, 'Search': 1, ':': 2, 'MI': 2, 'Ana...
# 240984    {'Sales': 6, 'M': 2, 'anager': 1, 'My': 1, 'cl...
# Name: wt, Length: 10000, dtype: object

# %% [markdown]
# Accumulating all the frequencies in a single dictionary with words as key and frequency as values

# %%
resultword={}
def accumulateword(dict):
    for key, value in dict.items():
        if key in resultword.keys():
            resultword[key] +=value
        else:
            resultword[key] = value

rev_data['wt'].map(accumulateword)
resultword
# Out:
# {'A': 3869,
#  'Marketing': 1010,
#  'Executive': 1099,
#  'is': 24309,
#  'required': 5145,
#  'to': 77163,
#  'join': 3723,
#  'a': 58072,
#  'global': 1064,
#  'value': 645,
#  'added': 76,
#  'distributor': 44,
#  'of': 58745,
#  'unified': 9,
#  'communications': 532,
#  'currently': 2131,
#  'based': 4050,
#  'in': 40411,
#  'Burgess': 14,
#  'Hill': 47,
#  '.': 87762,
#  'You': 8687,
#  'will': 26820,
#  'have': 13945,
#  'the': 72241,
#  'responsibility': 1060,
#  'for': 33760,
#  'day': 1709,
#  'marketing': 1603,
#  'within': 8756,
#  'department': 889,
#  'as': 17090,
#  'defined': 302,
#  'by': 4487,
#  'activities': 1097,
#  'below': 363,
#  'This': 9053,
#  'role': 10530,
#  'an': 17004,
#  'integral': 135,
#  'member': 453,
#  'small': 707,
#  'but': 2019,
#  'busy': 860,
#  'team': 9641,
#  'Key': 1331,
#  'attributes': 146,
#  'be': 24846,
#  'proactively': 172,
#  'engaged': 52,
#  'with': 29088,
#  'GTM': 3,
#  'and': 108353,
#  'business': 8159,
#  'touchpoints': 1,
#  'that': 8360,
#  'works': 365,
#  'internally': 149,
#  'vendors': 101,
#  'customers': 2356,
#  'when': 992,
#  'The': 12766,
#  'ideal': 1272,
#  'candidate': 3408,
#  ',': 95655,
#  'enjoy': 413,
#  'working': 7513,
#  'across': 2584,
#  'broad': 252,
#  'mix': 147,
#  'They': 1770,
#  'involved': 730,
#  'planning': 1077,
#  'execution': 189,
#  'follows': 86,
#  ':': 17832,
#  'Responsibilities': 933,
#  'Include': 41,
#  'Events': 71,
#  'Proactive': 101,
#  'measuring': 42,
#  'events': 437,
#  'including': 3715,
#  'management': 5639,
#  'company': 5776,
#  "'": 1130,
#  'internal': 1257,
#  'external': 890,
#  'partner': 211,
#  'industry': 2094,
#  'Marcomms': 2,
#  'design': 2654,
#  'broadcast': 20,
#  'using': 1410,
#  "'s": 2420,
#  'emarketing': 12,
#  'platform': 208,
#  'Design': 1019,
#  'created': 180,
#  'collateral': 56,
#  'presentation': 340,
#  'materials': 352,
#  'Creating': 97,
#  'front': 228,
#  'end': 652,
#  'web': 738,
#  'content': 289,
#  'CMS': 82,
#  'manage': 1692,
#  'website': 870,
#  'Ensure': 987,
#  'good': 2294,
#  'budget': 469,
#  'metrics': 80,
#  'relevant': 1787,
#  'parties': 162,
#  'Manage': 604,
#  'vendor': 94,
#  'funding': 109,
#  'withing': 1,
#  'programmes': 470,
#  'managing': 1658,
#  'quarterly': 104,
#  'claims': 173,
#  'process': 1800,
#  'collating': 33,
#  'information': 2427,
#  'claiming': 5,
#  'ensuring': 1569,
#  'successful': 4425,
#  'are': 16856,
#  'made': 338,
#  'Quarterly': 32,
#  'reporting': 1051,
#  'claim': 45,
#  'amounts': 42,
#  'Produce': 156,
#  'reports': 954,
#  'ROI': 45,
#  'on': 15859,
#  'use': 1293,
#  'Supporting': 181,
#  'sales': 5038,
#  'teams': 1394,
#  'resellers': 11,
#  'Candidate': 409,
#  'Looking': 128,
#  'marketeer': 2,
#  'minimum': 785,
#  '4': 371,
#  'years': 2303,
#  'B2B': 266,
#  'environment': 3688,
#  'Ability': 1350,
#  'combine': 46,
#  'creative': 595,
#  'skills': 8266,
#  'broader': 31,
#  'individual': 1365,
#  'should': 1332,
#  'passionate': 504,
#  'about': 1385,
#  'proactive': 516,
#  'accountable': 110,
#  'excellent': 3978,
#  'organisational': 477,
#  'project': 2499,
#  'combined': 124,
#  'eye': 214,
#  'attention': 518,
#  'detail': 835,
#  'cando': 46,
#  'attitude': 605,
#  'essential': 2504,
#  'work': 10487,
#  'both': 2208,
#  'budgets': 346,
#  'deadlines': 491,
#  'report': 490,
#  'demonstrate': 1001,
#  'having': 316,
#  'range': 1928,
#  'responsibilities': 879,
#  'ability': 2892,
#  'multiple': 570,
#  'projects': 2606,
#  'prioritise': 240,
#  'effectively': 790,
#  'Excellent': 1939,
#  'communication': 2501,
#  'written': 871,
#  'oral': 146,
#  'Good': 1200,
#  'worker': 75,
#  'versatile': 18,
#  'resilient': 45,
#  'Strong': 1343,
#  'customer': 3827,
#  'focus': 694,
#  'people': 2321,
#  'at': 6728,
#  'all': 8415,
#  'levels': 1326,
#  'Initially': 37,
#  'located': 254,
#  'then': 1339,
#  'Crawley': 47,
#  'Product': 421,
#  'Knowledge/Application': 1,
#  'Skills': 1265,
#  'Adobe': 55,
#  'Creative': 137,
#  'Suite': 49,
#  'photoshop': 3,
#  'illustrator': 2,
#  'InDesign': 20,
#  'intermediate/advanced': 4,
#  'level': 2657,
#  'Web/html/email': 1,
#  'Dreamweaver': 21,
#  'or': 12670,
#  'similar': 916,
#  'Microsoft': 1010,
#  'Office': 872,
#  'Outlook': 121,
#  'Word': 328,
#  'Excel': 627,
#  '(': 9506,
#  'int/advanced': 2,
#  ')': 9777,
#  'Powerpoint': 29,
#  'Sharepoint': 72,
#  'Knowledge': 958,
#  'IT/Telco': 1,
#  'desirable': 677,
#  'qualification': 884,
#  'Senior': 1813,
#  'Analyst': 808,
#  'responsible': 2335,
#  'production': 925,
#  'BI': 146,
#  'solutions': 1818,
#  'supporting': 801,
#  'artifacts': 3,
#  'appropriate': 1145,
#  'quality': 2511,
#  'time': 2564,
#  'scale': 246,
#  'agreed': 548,
#  'stakeholders': 567,
#  'involves': 248,
#  'building': 851,
#  'implementing': 397,
#  'cutting': 194,
#  'edge': 239,
#  'strategies': 438,
#  'analysing': 132,
#  'existing': 1273,
#  'databases': 191,
#  'requirements': 2385,
#  'deploy': 20,
#  'secure': 278,
#  'SQL': 1306,
#  'Server': 968,
#  '2008': 110,
#  'database': 512,
#  'Business': 2694,
#  'Intelligence': 136,
#  'play': 268,
#  'key': 2014,
#  'lead': 1168,
#  'lifecycle': 257,
#  'leads': 303,
#  'technical': 2522,
#  'has': 3744,
#  'overall': 342,
#  'facilitating': 42,
#  'major': 621,
#  'decisions': 238,
#  'line': 1259,
#  'strategic': 560,
#  'Architectural': 17,
#  'constraints': 54,
#  'typically': 59,
#  'includes': 392,
#  'identifying': 263,
#  'documenting': 54,
#  'architecturally': 2,
#  'significant': 464,
#  'aspects': 720,
#  'system': 1172,
#  'views': 35,
#  'describe': 21,
#  'implementation': 703,
#  'deployment': 134,
#  'also': 3511,
#  'providing': 1631,
#  'rationale': 4,
#  'these': 809,
#  'balancing': 29,
#  'concerns': 61,
#  'various': 636,
#  'reducing': 39,
#  'risks': 180,
#  'communicated': 37,
#  'validated': 9,
#  'followed': 91,
#  'several': 244,
#  'experience': 13535,
#  'roles': 780,
#  'adept': 29,
#  'translating': 28,
#  'needs': 1547,
#  'into': 1974,
#  'data': 1734,
#  'knowledge': 3400,
#  'technologies': 811,
#  'query': 29,
#  'standard': 764,
#  'strong': 2899,
#  'player': 477,
#  'great': 1606,
#  'interpersonal': 506,
#  'you': 19402,
#  'able': 3220,
#  'present': 246,
#  'results': 596,
#  'analysis': 1067,
#  'users': 475,
#  'Above': 38,
#  'selfmotivated': 181,
#  'flexible': 891,
#  'adaptable': 94,
#  'enough': 39,
#  'comfortably': 14,
#  'fast': 748,
#  'moving': 169,
#  'competitive': 924,
#  'Applicants': 494,
#  'must': 3991,
#  'very': 1564,
#  'background': 1663,
#  '2005/****': 22,
#  'Reporting': 562,
#  'Services': 1398,
#  'Analysis': 236,
#  'Integration': 114,
#  'Database': 184,
#  'ETL': 58,
#  'Experience': 3679,
#  'Management': 2077,
#  'Information': 356,
#  'would': 3056,
#  'extremely': 269,
#  'beneficial': 336,
#  'respond': 443,
#  'requests': 281,
#  'research': 644,
#  ';': 4641,
#  'produce': 399,
#  'useful': 80,
#  'insight': 168,
#  'valuable': 72,
#  'from': 6550,
#  'raw': 32,
#  'sources': 113,
#  'recognise': 58,
#  'extract': 21,
#  'critical': 263,
#  'indicators': 33,
#  'large': 1433,
#  'complex': 852,
#  'sets': 82,
#  'evaluate': 113,
#  'maintain': 1025,
#  'optimise': 65,
#  'intranet': 34,
#  'performance': 1534,
#  'processes': 1184,
#  'measurement': 66,
#  'tracking': 122,
#  'traffic': 55,
#  'analytical': 534,
#  'create': 451,
#  'high': 3453,
#  'deliver': 1356,
#  'accurate': 603,
#  'timely': 477,
#  'solid': 364,
#  'proven': 1153,
#  'fastmoving': 16,
#  'where': 1423,
#  'paramount': 49,
#  'verbal': 485,
#  'interact': 88,
#  'director': 93,
#  'outstanding': 596,
#  'skill': 267,
#  'superior': 34,
#  'uptodate': 114,
#  'through': 2470,
#  'reading': 51,
#  'publications/journals': 1,
#  'undertaking': 144,
#  'training': 3294,
#  'development': 5255,
#  'needed': 433,
#  'fulfill': 18,
#  'depend': 16,
#  'upon': 339,
#  'size': 132,
#  'complexity': 34,
#  'least': 801,
#  'some': 1373,
#  'degree': 912,
#  '2005': 37,
#  'considered': 1102,
#  'SSRS': 77,
#  'SSIS': 89,
#  'SSAS': 54,
#  'Data': 562,
#  'Mining': 16,
#  'CRM': 363,
#  'Techniques': 12,
#  'Preferable': 9,
#  'Campaign': 59,
#  'applications': 2327,
#  'processing': 336,
#  'manipulation': 39,
#  'Tools': 38,
#  'MDX': 12,
#  'Queries': 15,
#  'Dataloads': 1,
#  'rewriting': 6,
#  'dataloads': 1,
#  'stored': 61,
#  'procedures': 1183,
#  'Full': 716,
#  'understanding': 1921,
#  'intelligence': 93,
#  'practices': 391,
#  'used': 451,
#  'enterprise': 198,
#  'warehouse': 130,
#  'transformation': 79,
#  'loading': 37,
#  'techniques': 421,
#  'source': 156,
#  'systems': 2403,
#  'warehouses': 7,
#  'OLAP': 11,
#  'principals': 7,
#  'such': 1474,
#  'multidimensional': 4,
#  'star': 110,
#  'schemas': 6,
#  'meet': 1133,
#  'user': 395,
#  '.Net': 230,
#  'coding': 125,
#  'C': 1408,
#  'Visual': 140,
#  'Basic': 630,
#  'Any': 282,
#  'exposure': 449,
#  'Java': 644,
#  'advantageous': 423,
#  'Lead': 597,
#  'Developer': 1453,
#  'Front': 162,
#  'Rates': 29,
#  'Derivates': 3,
#  'Trade': 354,
#  'Processing': 132,
#  '/': 5777,
#  'Multithreading': 13,
#  'Spring': 161,
#  'JMS/': 3,
#  'Core': 107,
#  'Java/': 4,
#  'Agile/': 4,
#  'TDD****': 1,
#  '****': 19249,
#  'Bonus': 343,
#  'BenefitsMy': 1,
#  'client': 7018,
#  'investment': 316,
#  'bank': 304,
#  'city': 134,
#  'London': 2495,
#  'With': 745,
#  'success': 941,
#  'they': 2367,
#  'had': 244,
#  'over': 1615,
#  'past': 141,
#  '23': 92,
#  'looking': 6219,
#  'hire': 176,
#  'become': 582,
#  'part': 2394,
#  'risk': 683,
#  'Fixed': 133,
#  'Income': 51,
#  'Technology': 245,
#  'rates': 375,
#  'derivatives': 15,
#  'trade': 254,
#  'expected': 704,
#  'programming': 333,
#  'efforts': 82,
#  'person': 776,
#  'participate': 169,
#  'peer': 17,
#  'code': 221,
#  'review': 520,
#  'one': 2453,
#  'programs': 132,
#  'IT': 2118,
#  'which': 2357,
#  'delivered': 276,
#  'successfully': 247,
#  'need': 2454,
#  'daily': 612,
#  'basis': 1139,
#  'other': 3071,
#  'New': 450,
#  'York': 86,
#  'Singapore': 23,
#  'Technical': 954,
#  'TDDThe': 2,
#  'At': 335,
#  '5': 683,
#  'JavaMultithreadingSpringJMS': 1,
#  'MQ': 11,
#  'SeriesTDD/': 1,
#  'BDD': 31,
#  'Agile': 286,
#  'methodologyMust': 1,
#  'FIXED': 2,
#  'INCOME': 1,
#  'EQUITIESPersonality': 1,
#  'TDDDemonstrate': 1,
#  'commitment': 474,
#  'organisation': 1963,
#  'roleMaintain': 1,
#  'professionalism': 64,
#  'timesBuild': 1,
#  'relationships': 1480,
#  'colleaguesBe': 1,
#  'efficient': 448,
#  'effective': 1108,
#  'fully': 588,
#  'achieve': 801,
#  'goalsContinuously': 1,
#  'seek': 198,
#  'improvement': 535,
#  'higher': 136,
#  'efficiency': 203,
#  'service': 4375,
#  'effectivenessRecognise': 1,
#  'importance': 102,
#  'order': 1109,
#  'clarity': 10,
#  'workplace': 110,
#  'workPossess': 1,
#  'initiative': 503,
#  'independently': 247,
#  'confidence': 364,
#  'take': 1495,
#  'madeA': 1,
#  'methodical': 54,
#  'approach': 1113,
#  'enthusiasm': 245,
#  'correctness': 2,
#  'completeness': 12,
#  'resultsDeadline': 1,
#  'focusedHigh': 1,
#  'energy': 378,
#  'can': 3148,
#  'do': 1442,
#  'approachSystematic': 1,
#  'structured': 208,
#  'converse': 17,
#  'communicate': 487,
#  'teams.Team': 1,
#  'playerOwnership': 1,
#  'workloadCan': 1,
#  'think': 240,
#  'beyond': 128,
#  'their': 7400,
#  'own': 1620,
#  'impact': 277,
#  'actions': 225,
#  'wider': 200,
#  'environmentResilient': 1,
#  'self': 337,
#  'motivatedPlease': 1,
#  'forward': 1083,
#  'your': 10210,
#  'CV': 3333,
#  'eobiechefuargyllscott.com': 1,
#  'call': 1695,
#  'me': 488,
#  'term': 798,
#  '12': 297,
#  'months': 771,
#  'Student': 24,
#  'Systems': 697,
#  'SIMS': 5,
#  'provides': 430,
#  'comprehensive': 295,
#  'bespoke': 269,
#  'support': 4865,
#  'University': 206,
#  '’': 2038,
#  's': 3284,
#  'provision': 332,
#  'student': 84,
#  'active': 223,
#  'students': 342,
#  'wide': 721,
#  'staff': 2566,
#  'Central': 386,
#  'Administration': 200,
#  'Faculties': 1,
#  'requiring': 66,
#  'well': 3368,
#  'analyst': 118,
#  'understand': 496,
#  'them': 1156,
#  'develop': 2336,
#  'Oracle': 409,
#  'software': 1858,
#  'PL/SQL': 46,
#  'Forms': 45,
#  'Reports': 88,
#  'designing': 239,
#  'developing': 1455,
#  'situations': 111,
#  'identify': 499,
#  'build': 1008,
#  'focused': 658,
#  'under': 808,
#  'pressure': 457,
#  'priorities': 151,
#  'while': 232,
#  'maintaining': 631,
#  'flexibility': 188,
#  'Education': 561,
#  'e.g': 431,
#  'Banner': 2,
#  'issues': 1243,
#  'Higher': 39,
#  'Grade': 90,
#  'p': 12,
#  '.a': 1,
#  'Informal': 22,
#  'enquiries': 324,
#  'may': 1246,
#  'Peter': 17,
#  'Bindon': 1,
#  'Service': 1380,
#  'Group': 1172,
#  'Leader': 347,
#  'tel': 13,
#  'email': 1582,
#  'p.j.f.bindonleeds.ac.uk': 1,
#  'Ref': 289,
#  'CSISS****': 1,
#  'We': 4720,
#  'recruiting': 973,
#  'HR': 1109,
#  'Project': 1323,
#  'Manager': 6266,
#  'leading': 3411,
#  'multisite': 50,
#  'truly': 223,
#  'generalist': 74,
#  'network': 522,
#  'Working': 1569,
#  'units': 122,
#  'championing': 17,
#  'delivering': 1012,
#  'strategy': 702,
#  'robust': 146,
#  'advice': 564,
#  'Performance': 137,
#  'Indicators': 13,
#  'Delivery': 214,
#  'agenda': 59,
#  'Successful': 321,
#  'change': 702,
#  'initiatives': 262,
#  'Levels': 18,
#  'employee': 267,
#  'involvement': 108,
#  'engagement': 151,
#  'Adherence': 13,
#  'completion': 312,
#  'site': 1188,
#  'plans': 962,
#  'unit': 231,
#  'Main': 448,
#  'Duties': 601,
#  'Develop': 505,
#  'industrial': 212,
#  'relations': 155,
#  'union': 9,
#  'national': 497,
#  'Give': 11,
#  'contracts': 477,
#  'Company': 1454,
#  'policy': 467,
#  'best': 1525,
#  'practice': 881,
#  'advise': 150,
#  'employment': 1682,
#  'law': 218,
#  'any': 2011,
#  'applicable': 156,
#  'local': 846,
#  'agreements': 96,
#  'Investigation': 19,
#  'Disciplinary': 13,
#  'Maternity': 44,
#  'Paternity': 1,
#  'Family': 59,
#  'Friendly': 39,
#  'polices': 9,
#  'etc': 1025,
#  'Support': 1412,
#  'National': 298,
#  'TU': 2,
#  'forums': 16,
#  'meetings': 715,
#  'Wage': 8,
#  'Negs': 1,
#  'Communications': 155,
#  'Forum': 8,
#  'FAB': 1,
#  'Disputes': 4,
#  'Committees': 8,
#  'Development': 1483,
#  'workshops': 84,
#  'rolled': 9,
#  'out': 2194,
#  'sites': 526,
#  'capability': 196,
#  'Implementation': 126,
#  'continuous': 322,
#  'monitoring/improvement': 1,
#  'absence': 172,
#  'policies': 557,
#  'associated': 363,
#  'sickness': 78,
#  'preemployment': 18,
#  'OH': 15,
#  'coordination': 136,
#  'Producing': 99,
#  'weekly/monthly': 9,
#  'interrogating': 5,
#  'SAP': 306,
#  'ensure': 3082,
#  'utilised': 23,
#  'Provide': 731,
#  'operational': 586,
#  'this': 11040,
#  'involve': 640,
#  'attendance': 66,
#  'central': 234,
#  'function': 430,
#  'adhoc': 100,
#  'TUPE': 24,
#  'Pensions': 49,
#  'maintained': 328,
#  'problems': 437,
#  'dealt': 66,
#  'early': 157,
#  'stage': 251,
#  'CIPD': 70,
#  'studying': 26,
#  'towards': 454,
#  'Extensive': 202,
#  'Human': 81,
#  'Resources': 140,
#  'preferably': 446,
#  'paced': 426,
#  'Up': 329,
#  'date': 992,
#  'Employment': 1684,
#  'Law': 131,
#  'Union': 22,
#  'Trustworthy': 3,
#  'completely': 37,
#  'confidential': 250,
#  'influence': 214,
#  'influences': 9,
#  'outcomes': 125,
#  'necessary': 861,
#  'Looks': 3,
#  'exercise': 22,
#  'discretion': 31,
#  'confidentiality': 69,
#  'times': 746,
#  'Identifies': 21,
#  'others': 452,
#  'Presents': 4,
#  'professionally': 129,
#  'Displays': 1,
#  'exceptional': 572,
#  'drive': 984,
#  'tenacity': 26,
#  'Understands': 24,
#  'drives': 39,
#  'goals': 306,
#  'builds': 52,
#  'Outstanding': 135,
#  'In': 1788,
#  'return': 692,
#  'hard': 377,
#  'receive': 1144,
#  'car': 691,
#  'An': 1254,
#  'annual': 451,
#  'bonus': 954,
#  'up': 2832,
#  '25': 344,
#  '%': 800,
#  'depending': 410,
#  'Private': 256,
#  'Health': 1103,
#  'Care': 923,
#  'days': 1738,
#  'leave': 223,
#  'Defined': 4,
#  'contribution': 151,
#  'pension': 612,
#  'scheme': 856,
#  'job': 4733,
#  'was': 2923,
#  'originally': 2752,
#  'posted': 2778,
#  'www.totaljobs.com/JobSeeking/HRProjectManager_job****': 1,
#  'Just': 31,
#  'Social': 489,
#  'seeking': 1341,
#  'children': 681,
#  'workers': 370,
#  'residential': 329,
#  'setting': 445,
#  'supportive': 216,
#  'nurturing': 26,
#  'young': 350,
#  'profound': 4,
#  'learning': 645,
#  'difficulties': 65,
#  'ADHD': 5,
#  'physical': 145,
#  'disabilities': 145,
#  'closeknit': 22,
#  'four': 96,
#  'houses': 53,
#  'assist': 785,
#  'everyday': 34,
#  'personal': 791,
#  'care': 2568,
#  'education': 373,
#  'treatment': 154,
#  'PMLD': 5,
#  'Two': 32,
#  'shifts': 329,
#  'per': 1967,
#  'weekend': 130,
#  'late': 56,
#  'motivated': 797,
#  'committed': 735,
#  'calm': 79,
#  'not': 3500,
#  'standards': 1703,
#  'Minimum': 257,
#  'NVQ****': 14,
#  'enhanced': 236,
#  'CRB': 401,
#  'happy': 302,
#  'apply': 3416,
#  'two': 512,
#  'field': 714,
#  'For': 1427,
#  'more': 2521,
#  'details': 1178,
#  'post': 1031,
#  'please': 4477,
#  'click': 315,
#  'today': 556,
#  'most': 1011,
#  'experienced': 2530,
#  'consultants': 443,
#  'UK': 4568,
#  'who': 4685,
#  '15': 93,
#  'Work': 1054,
#  'recruitment': 2631,
#  'Locum': 40,
#  'permanent': 1300,
#  'placements': 69,
#  'Graduate': 545,
#  'Software': 930,
#  'Web': 690,
#  'PHP': 280,
#  'MySQL': 148,
#  'Enfield': 20,
#  '****K': 636,
#  'exciting': 1645,
#  'new': 4889,
#  'graduate': 466,
#  'if': 1858,
#  've': 91,
#  'recently': 193,
#  'studied': 21,
#  'internet': 99,
#  'achieved': 316,
#  'pass': 117,
#  'mark': 69,
#  'detailed': 349,
#  'schedule': 169,
#  'ready': 171,
#  'graduates': 129,
#  'make': 1131,
#  'teaching': 568,
#  'elements': 119,
#  'If': 3286,
#  'enthusiastic': 581,
#  'recent': 394,
#  'Computer': 320,
#  'Science': 290,
#  'Internet': 57,
#  'above': 671,
#  'sure': 232,
#  'career': 2909,
#  'foundation': 36,
#  'taught': 17,
#  'there': 693,
#  'whole': 209,
#  'world': 937,
#  'opened': 76,
#  'onthejob': 8,
#  'll': 814,
#  'step': 315,
#  'straight': 66,
#  'learn': 498,
#  'LAMP': 46,
#  'HTML': 361,
#  'CSS': 327,
#  'JavaScript': 307,
#  'opportunities': 2709,
#  'here': 190,
#  'soon': 205,
#  'progress': 862,
#  'Junior': 234,
#  'There': 442,
#  'number': 1382,
#  're': 409,
#  'online': 1363,
#  'bluechip': 46,
#  'clients': 3529,
#  'include': 2438,
#  'ASP.Net': 201,
#  'C.': 11,
#  'junior': 236,
#  'developer': 398,
#  'interest': 648,
#  'get': 825,
#  'touch': 274,
#  'send': 1398,
#  'directly': 569,
#  'Hannah.olcroftsenitor.com': 1,
#  'Keywords': 155,
#  'Training': 502,
#  'Senitor': 18,
#  'Associates': 199,
#  'Ltd': 763,
#  'acting': 1112,
#  'Agency': 1221,
#  'relation': 905,
#  'vacancy': 1515,
#  'My': 1425,
#  'PR': 226,
#  'Account': 998,
#  'award': 325,
#  'winning': 402,
#  'agency': 1669,
#  'offering': 736,
#  'opportunity': 5180,
#  'biggest': 91,
#  'brands': 305,
#  'whilst': 725,
#  'being': 1227,
#  'incorporated': 9,
#  'innovative': 655,
#  ...}

# %% [markdown]
# Selecting top 100 common words based on frequency

# %%
from operator import itemgetter
topword = sorted(resultword.items(), key=itemgetter(1), reverse=True)[:100]
topword
# Out:
# [('and', 108353),
#  (',', 95655),
#  ('.', 87762),
#  ('to', 77163),
#  ('the', 72241),
#  ('of', 58745),
#  ('a', 58072),
#  ('in', 40411),
#  ('for', 33760),
#  ('with', 29088),
#  ('will', 26820),
#  ('be', 24846),
#  ('is', 24309),
#  ('you', 19402),
#  ('****', 19249),
#  (':', 17832),
#  ('as', 17090),
#  ('an', 17004),
#  ('are', 16856),
#  ('on', 15859),
#  ('have', 13945),
#  ('experience', 13535),
#  ('The', 12766),
#  ('or', 12670),
#  ('this', 11040),
#  ('role', 10530),
#  ('work', 10487),
#  ('your', 10210),
#  (')', 9777),
#  ('team', 9641),
#  ('(', 9506),
#  ('This', 9053),
#  ('within', 8756),
#  ('You', 8687),
#  ('all', 8415),
#  ('that', 8360),
#  ('skills', 8266),
#  ('business', 8159),
#  ('working', 7513),
#  ('their', 7400),
#  ('client', 7018),
#  ('at', 6728),
#  ('our', 6600),
#  ('from', 6550),
#  ('Manager', 6266),
#  ('looking', 6219),
#  ('/', 5777),
#  ('company', 5776),
#  ('management', 5639),
#  ('To', 5496),
#  ('development', 5255),
#  ('opportunity', 5180),
#  ('required', 5145),
#  ('sales', 5038),
#  ('we', 4891),
#  ('new', 4889),
#  ('support', 4865),
#  ('job', 4733),
#  ('We', 4720),
#  ('who', 4685),
#  (';', 4641),
#  ('UK', 4568),
#  ('by', 4487),
#  ('please', 4477),
#  ('successful', 4425),
#  ('service', 4375),
#  ('based', 4050),
#  ('must', 3991),
#  ('excellent', 3978),
#  ('A', 3869),
#  ('customer', 3827),
#  ('has', 3744),
#  ('join', 3723),
#  ('including', 3715),
#  ('environment', 3688),
#  ('Experience', 3679),
#  ('clients', 3529),
#  ('also', 3511),
#  ('not', 3500),
#  ('high', 3453),
#  ('apply', 3416),
#  ('leading', 3411),
#  ('candidate', 3408),
#  ('knowledge', 3400),
#  ('well', 3368),
#  ('?', 3341),
#  ('CV', 3333),
#  ('Sales', 3321),
#  ('training', 3294),
#  ('If', 3286),
#  ('s', 3284),
#  ('able', 3220),
#  ('position', 3152),
#  ('can', 3148),
#  ('ensure', 3082),
#  ('other', 3071),
#  ('would', 3056),
#  ('services', 3019),
#  ('was', 2923),
#  ('career', 2909)]

# %% [markdown]
# Converting the dictionary to a dataframe.

# %%
keys_freq = []
values_freq = []
xaxis = range(len(topword))
for key, value in topword:
    keys_freq.append(key)
    values_freq.append(value)

# %%
df = pd.DataFrame({'col1word':keys_freq, 'count':values_freq})
df['Rank'] = df['count'].rank(ascending=False)
df['RF'] = df['Rank']*df['count']
df
# Out:
#        col1word   count   Rank        RF
# 0           and  108353    1.0  108353.0
# 1             ,   95655    2.0  191310.0
# 2             .   87762    3.0  263286.0
# 3            to   77163    4.0  308652.0
# 4           the   72241    5.0  361205.0
# 5            of   58745    6.0  352470.0
# 6             a   58072    7.0  406504.0
# 7            in   40411    8.0  323288.0
# 8           for   33760    9.0  303840.0
# 9          with   29088   10.0  290880.0
# 10         will   26820   11.0  295020.0
# 11           be   24846   12.0  298152.0
# 12           is   24309   13.0  316017.0
# 13          you   19402   14.0  271628.0
# 14         ****   19249   15.0  288735.0
# 15            :   17832   16.0  285312.0
# 16           as   17090   17.0  290530.0
# 17           an   17004   18.0  306072.0
# 18          are   16856   19.0  320264.0
# 19           on   15859   20.0  317180.0
# 20         have   13945   21.0  292845.0
# 21   experience   13535   22.0  297770.0
# 22          The   12766   23.0  293618.0
# 23           or   12670   24.0  304080.0
# 24         this   11040   25.0  276000.0
# 25         role   10530   26.0  273780.0
# 26         work   10487   27.0  283149.0
# 27         your   10210   28.0  285880.0
# 28            )    9777   29.0  283533.0
# 29         team    9641   30.0  289230.0
# ..          ...     ...    ...       ...
# 70     customer    3827   71.0  271717.0
# 71          has    3744   72.0  269568.0
# 72         join    3723   73.0  271779.0
# 73    including    3715   74.0  274910.0
# 74  environment    3688   75.0  276600.0
# 75   Experience    3679   76.0  279604.0
# 76      clients    3529   77.0  271733.0
# 77         also    3511   78.0  273858.0
# 78          not    3500   79.0  276500.0
# 79         high    3453   80.0  276240.0
# 80        apply    3416   81.0  276696.0
# 81      leading    3411   82.0  279702.0
# 82    candidate    3408   83.0  282864.0
# 83    knowledge    3400   84.0  285600.0
# 84         well    3368   85.0  286280.0
# 85            ?    3341   86.0  287326.0
# 86           CV    3333   87.0  289971.0
# 87        Sales    3321   88.0  292248.0
# 88     training    3294   89.0  293166.0
# 89           If    3286   90.0  295740.0
# 90            s    3284   91.0  298844.0
# 91         able    3220   92.0  296240.0
# 92     position    3152   93.0  293136.0
# 93          can    3148   94.0  295912.0
# 94       ensure    3082   95.0  292790.0
# 95        other    3071   96.0  294816.0
# 96        would    3056   97.0  296432.0
# 97     services    3019   98.0  295862.0
# 98          was    2923   99.0  289377.0
# 99       career    2909  100.0  290900.0
#
# [100 rows x 4 columns]

# %% [markdown]
# Plotting log-log graph of frequency against rank

# %%
import numpy
from matplotlib import pyplot as plt
# %pylab inline
import math
logA = numpy.log10(df['count'])
logB = numpy.log10(df['Rank'])
plt.plot(logB, logA)
plt.ylabel('log(Frequency of words)')
plt.xlabel('log(Rank based on frequency)')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# The corpus supports Zipf's law. For rank around 1-10, the value of k differs from the vlaue of k after rank 10

# %%
logA = numpy.log10(df['count'])
logB = numpy.log10(df['Rank'])
plt.plot(df['Rank'], df['RF'])
plt.ylabel('Frequency rank product')
plt.xlabel('Rank based on frequency')

# %% [markdown]
# While plotting rank against the product of rank and frequency by putting k as 1, we see that the graph is straight after rank 10. So the value of k for ranks below 10 are different.

# %% [markdown]
# A3. If we remove stopwords and lemmatize the corpus, what are the 10 most common words? What are their frequencies?

# %% [markdown]
# Solution:
# Removing stop words and lemmatizing the corpus

# %%
from nltk.corpus import stopwords
import string
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
corpus=[]
def tokenizes(item):
    stop = stopwords.words('english') + list(string.punctuation)
    text = [i for i in nltk.word_tokenize(item.lower()) if i not in stop]
    lem = list(map(lemmatizer.lemmatize, text))
    corpus.append(lem)
rev_data["FullDescription"].apply(tokenizes)
rev_data["Description_corpus_stoplem"]=corpus
rev_data["Description_corpus_stoplem"]=rev_data["Description_corpus_stoplem"].astype(str)

# %% [markdown]
# Counting the frequency of each word in each row

# %%
from collections import Counter
def wordcount(s):
    return Counter([i for i in nltk.word_tokenize(s)])

rev_data['stoplem']=rev_data['Description_corpus_stoplem'].apply(wordcount)
rev_data['stoplem']
# Out:
# 190731    {'[': 1, ''marketing': 14, ''': 269, ',': 271,...
# 88950     {'[': 1, ''senior': 1, ''': 380, ',': 379, ''a...
# 51163     {'[': 1, ''lead': 7, ''': 228, ',': 227, ''jav...
# 155224    {'[': 1, ''fixed': 1, ''': 152, ',': 150, ''te...
# 61106     {'[': 1, ''currently': 1, ''': 295, ',': 293, ...
# 607       {'[': 1, ''social': 4, ''': 118, ',': 116, ''c...
# 45539     {'[': 1, ''graduate': 4, ''': 136, ',': 135, '...
# 118084    {'[': 1, ''client': 4, ''': 174, ',': 173, ''c...
# 170393    {'[': 1, ''theatre': 3, ''': 184, ',': 183, ''...
# 71489     {'[': 1, ''compiler': 10, ''': 122, ',': 121, ...
# 146463    {'[': 1, ''client': 1, ''': 62, ',': 61, ''lea...
# 137799    {'[': 1, ''convergence/mobile': 3, ''': 264, '...
# 92460     {'[': 1, ''ucl': 5, ''': 139, ',': 138, ''deve...
# 3073      {'[': 1, ''care': 7, ''': 110, ',': 108, ''ass...
# 28699     {'[': 1, ''successful': 1, ''': 79, ',': 78, '...
# 89421     {'[': 1, ''36': 1, ''': 87, ',': 86, ''hour': ...
# 201109    {'[': 1, ''internal': 5, ''': 288, ',': 287, '...
# 45130     {'[': 1, ''client': 2, ''': 140, ',': 139, ''b...
# 213435    {'[': 1, ''role': 2, ''': 205, ',': 202, ''•ke...
# 128982    {'[': 1, ''senior': 2, ''': 262, ',': 261, ''q...
# 131916    {'[': 1, ''client': 2, ''': 124, ',': 123, ''g...
# 51917     {'[': 1, ''major': 1, ''': 123, ',': 122, ''co...
# 47183     {'[': 1, ''world': 2, ''': 123, ',': 122, ''he...
# 78463     {'[': 1, ''looking': 1, ''': 129, ',': 128, ''...
# 150116    {'[': 1, ''education': 4, ''': 146, ',': 145, ...
# 6671      {'[': 1, ''senior': 1, ''': 84, ',': 83, ''sof...
# 240500    {'[': 1, ''project': 16, ''': 215, ',': 216, '...
# 86791     {'[': 1, ''free': 2, ''': 224, ',': 223, ''reg...
# 25591     {'[': 1, ''junior': 2, ''': 191, ',': 190, ''h...
# 128636    {'[': 1, ''redrock': 1, ''': 139, ',': 138, ''...
#                                 ...
# 99762     {'[': 1, ''client': 1, ''': 75, ',': 74, ''par...
# 183691    {'[': 1, ''design': 7, ''': 139, ',': 138, ''m...
# 232449    {'[': 1, ''year': 3, ''': 141, ',': 140, ''***...
# 161844    {'[': 1, ''introduction': 1, ''': 119, ',': 11...
# 68072     {'[': 1, ''fantastic': 1, ''': 78, ',': 75, ''...
# 29337     {'[': 1, ''clinical': 6, ''': 120, ',': 119, '...
# 150804    {'[': 1, ''requirement': 2, ''': 124, ',': 123...
# 84875     {'[': 1, ''working': 4, ''': 191, ',': 190, ''...
# 160374    {'[': 1, ''residential': 6, ''': 219, ',': 216...
# 164054    {'[': 1, ''medicspro': 2, ''': 76, ',': 75, ''...
# 113808    {'[': 1, ''job': 1, ''': 169, ',': 168, ''adve...
# 1711      {'[': 1, ''allied': 2, ''': 117, ',': 117, ''h...
# 145292    {'[': 1, ''business': 3, ''': 172, ',': 171, '...
# 98929     {'[': 1, ''general': 7, ''': 365, ',': 364, ''...
# 216281    {'[': 1, ''fantastic': 1, ''': 83, ',': 82, ''...
# 146349    {'[': 1, ''java': 13, ''': 246, ',': 245, ''de...
# 135668    {'[': 1, ''chef': 4, ''': 185, ',': 184, ''de'...
# 204750    {'[': 1, ''credit': 4, ''': 93, ',': 92, ''con...
# 118089    {'[': 1, ''experienced': 1, ''': 309, ',': 309...
# 107178    {'[': 1, ''observational': 12, ''': 276, ',': ...
# 201103    {'[': 1, ''junior': 7, ''': 181, ',': 180, ''....
# 39493     {'[': 1, ''computer': 2, ''': 84, ',': 83, ''p...
# 65439     {'[': 1, ''fm': 9, ''': 251, ',': 253, ''sourc...
# 2333      {'[': 1, ''location': 1, ''': 128, ',': 127, '...
# 232665    {'[': 1, ''possession': 3, ''': 97, ',': 96, '...
# 72706     {'[': 1, ''membership': 1, ''': 63, ',': 63, '...
# 161477    {'[': 1, ''chef': 3, ''': 57, ',': 56, ''neede...
# 779       {'[': 1, ''job': 2, ''': 113, ',': 114, ''ref'...
# 192496    {'[': 1, ''word': 1, ''': 203, ',': 204, ''sea...
# 240984    {'[': 1, ''sale': 7, ''': 159, ',': 158, ''ana...
# Name: stoplem, Length: 10000, dtype: object

# %%
resultword={}
def accumulatelem(dict):
    for key, value in dict.items():
        if key in resultword.keys():
            resultword[key] +=value
        else:
            resultword[key] = value

rev_data['stoplem'].map(accumulatelem)
resultword
# Out:
# {'[': 10000,
#  "'marketing": 2631,
#  "'": 1553487,
#  ',': 1545339,
#  "'executive": 1563,
#  "'required": 5693,
#  "'join": 3804,
#  "'global": 1438,
#  "'value": 893,
#  "'added": 87,
#  "'distributor": 113,
#  "'unified": 32,
#  "'communication": 3336,
#  "'currently": 2208,
#  "'based": 4495,
#  "'burgess": 14,
#  "'hill": 56,
#  "'responsibility": 3053,
#  "'day": 3744,
#  "'within": 8886,
#  "'department": 1602,
#  "'defined": 306,
#  "'activity": 1644,
#  "'role": 12758,
#  "'integral": 135,
#  "'member": 1317,
#  "'small": 746,
#  "'busy": 873,
#  "'team": 12349,
#  "'key": 3445,
#  "'attribute": 231,
#  "'proactively": 259,
#  "'engaged": 53,
#  "'gtm": 3,
#  "'business": 11362,
#  "'touchpoints": 2,
#  "'work": 12106,
#  "'internally": 150,
#  "'vendor": 253,
#  "'customer": 7100,
#  "'ideal": 1442,
#  "'candidate": 7291,
#  "'enjoy": 447,
#  "'working": 9125,
#  "'across": 2592,
#  "'broad": 293,
#  "'mix": 149,
#  "'involved": 743,
#  "'planning": 1425,
#  "'execution": 206,
#  "'follows": 89,
#  "'include": 2484,
#  "'event": 676,
#  "'proactive": 620,
#  "'measuring": 48,
#  "'including": 3758,
#  "'management": 7732,
#  "'company": 8423,
#  "'internal": 1473,
#  "'external": 931,
#  "'partner": 834,
#  "'industry": 2639,
#  "'marcomms": 5,
#  "'design": 3986,
#  "'broadcast": 23,
#  "'using": 1509,
#  '``': 4308,
#  "'s": 2466,
#  "''": 4298,
#  "'emarketing": 14,
#  "'platform": 456,
#  "'created": 181,
#  "'collateral": 62,
#  "'presentation": 569,
#  "'material": 638,
#  "'creating": 396,
#  "'front": 396,
#  "'end": 858,
#  "'web": 1439,
#  "'content": 349,
#  "'cm": 88,
#  "'manage": 2298,
#  "'website": 1106,
#  "'ensure": 4090,
#  "'good": 3664,
#  "'budget": 870,
#  "'metric": 84,
#  "'relevant": 1914,
#  "'party": 404,
#  "'funding": 120,
#  "'withing": 1,
#  "'programme": 1398,
#  "'managing": 2210,
#  "'quarterly": 138,
#  "'claim": 286,
#  "'process": 3281,
#  "'collating": 53,
#  "'information": 2847,
#  "'claiming": 5,
#  "'ensuring": 1933,
#  "'successful": 4769,
#  "'made": 348,
#  "'reporting": 1620,
#  "'amount": 189,
#  "'produce": 577,
#  "'report": 1653,
#  "'roi": 45,
#  "'use": 1441,
#  "'supporting": 982,
#  "'sale": 8606,
#  "'resellers": 16,
#  "'looking": 6366,
#  "'marketeer": 3,
#  "'minimum": 1056,
#  "'4": 372,
#  "'year": 3776,
#  "'b2b": 278,
#  "'environment": 4090,
#  "'ability": 4431,
#  "'combine": 60,
#  "'creative": 736,
#  "'skill": 9929,
#  "'broader": 31,
#  "'individual": 2106,
#  "'passionate": 564,
#  "'accountable": 149,
#  "'excellent": 5952,
#  "'organisational": 510,
#  "'project": 6596,
#  "'combined": 131,
#  "'eye": 224,
#  "'attention": 615,
#  "'detail": 2129,
#  "'cando": 63,
#  "'attitude": 631,
#  "'essential": 3183,
#  "'deadline": 543,
#  "'demonstrate": 1120,
#  "'range": 2009,
#  "'multiple": 607,
#  "'prioritise": 246,
#  "'effectively": 868,
#  "'written": 887,
#  "'oral": 154,
#  "'worker": 739,
#  "'versatile": 19,
#  "'resilient": 59,
#  "'strong": 4249,
#  "'focus": 805,
#  "'people": 2660,
#  "'level": 4467,
#  "'initially": 213,
#  "'located": 298,
#  "'crawley": 48,
#  "'product": 4042,
#  "'knowledge/application": 1,
#  "'adobe": 56,
#  "'suite": 174,
#  "'photoshop": 81,
#  "'illustrator": 45,
#  "'indesign": 28,
#  "'intermediate/advanced": 4,
#  "'web/html/email": 1,
#  "'dreamweaver": 22,
#  "'similar": 918,
#  "'microsoft": 1016,
#  "'office": 2902,
#  "'outlook": 200,
#  "'word": 566,
#  "'excel": 785,
#  "'int/advanced": 2,
#  "'powerpoint": 149,
#  "'sharepoint": 278,
#  "'knowledge": 4386,
#  "'it/telco": 1,
#  "'desirable": 1018,
#  "'qualification": 2118,
#  ']': 10000,
#  "'senior": 2915,
#  "'analyst": 1082,
#  "'responsible": 2742,
#  "'production": 1283,
#  "'bi": 153,
#  "'solution": 2613,
#  "'artifact": 3,
#  "'appropriate": 1164,
#  "'quality": 3368,
#  "'time": 3807,
#  "'scale": 308,
#  "'agreed": 549,
#  "'stakeholder": 814,
#  "'involves": 249,
#  "'building": 1278,
#  "'implementing": 433,
#  "'cutting": 203,
#  "'edge": 265,
#  "'strategy": 1275,
#  "'analysing": 168,
#  "'existing": 1292,
#  "'database": 909,
#  "'requirement": 3451,
#  "'deploy": 26,
#  "'secure": 310,
#  "'sql": 1322,
#  "'server": 1347,
#  "'2008": 110,
#  "'intelligence": 232,
#  "'play": 316,
#  "'lead": 2102,
#  "'lifecycle": 273,
#  "'technical": 3485,
#  "'overall": 391,
#  "'facilitating": 53,
#  "'major": 701,
#  "'decision": 528,
#  "'line": 1655,
#  "'strategic": 652,
#  "'architectural": 69,
#  "'constraint": 56,
#  "'typically": 79,
#  "'includes": 394,
#  "'identifying": 343,
#  "'documenting": 59,
#  "'architecturally": 2,
#  "'significant": 561,
#  "'aspect": 797,
#  "'system": 4526,
#  "'view": 406,
#  "'describe": 24,
#  "'implementation": 880,
#  "'deployment": 162,
#  "'also": 3629,
#  "'providing": 1935,
#  "'rationale": 6,
#  "'balancing": 37,
#  "'concern": 88,
#  "'various": 673,
#  "'reducing": 41,
#  "'risk": 1263,
#  "'communicated": 39,
#  "'validated": 9,
#  "'followed": 93,
#  "'several": 254,
#  "'experience": 17553,
#  "'adept": 43,
#  "'translating": 34,
#  "'need": 4099,
#  "'data": 2302,
#  "'technology": 2050,
#  "'query": 494,
#  "'standard": 2669,
#  "'player": 554,
#  "'great": 1867,
#  "'interpersonal": 529,
#  "'able": 3735,
#  "'present": 296,
#  "'result": 952,
#  "'analysis": 1344,
#  "'user": 1048,
#  "'selfmotivated": 236,
#  "'flexible": 1102,
#  "'adaptable": 110,
#  "'enough": 39,
#  "'comfortably": 15,
#  "'fast": 848,
#  "'moving": 181,
#  "'competitive": 1130,
#  "'applicant": 2175,
#  "'must": 5152,
#  "'background": 1968,
#  "'2005/****": 22,
#  "'service": 10220,
#  "'integration": 354,
#  "'etl": 58,
#  "'would": 3148,
#  "'extremely": 286,
#  "'beneficial": 381,
#  "'respond": 500,
#  "'request": 402,
#  "'research": 877,
#  "'useful": 86,
#  "'insight": 261,
#  "'valuable": 73,
#  "'raw": 35,
#  "'source": 352,
#  "'recognise": 66,
#  "'extract": 29,
#  "'critical": 306,
#  "'indicator": 52,
#  "'large": 1505,
#  "'complex": 889,
#  "'set": 899,
#  "'evaluate": 138,
#  "'maintain": 1461,
#  "'optimise": 74,
#  "'intranet": 45,
#  "'performance": 1686,
#  "'measurement": 93,
#  "'tracking": 142,
#  "'traffic": 73,
#  "'analytical": 609,
#  "'create": 601,
#  "'high": 3849,
#  "'deliver": 1483,
#  "'accurate": 638,
#  "'timely": 492,
#  "'solid": 497,
#  "'proven": 1734,
#  "'fastmoving": 16,
#  "'paramount": 66,
#  "'verbal": 497,
#  "'interact": 102,
#  "'director": 1116,
#  "'outstanding": 748,
#  "'superior": 38,
#  "'uptodate": 115,
#  "'reading": 200,
#  "'publications/journals": 1,
#  "'undertaking": 187,
#  "'training": 3829,
#  "'development": 6988,
#  "'needed": 462,
#  "'fulfill": 19,
#  "'depend": 16,
#  "'upon": 363,
#  "'size": 167,
#  "'complexity": 38,
#  "'least": 807,
#  "'degree": 1316,
#  "'2005": 37,
#  "'considered": 1116,
#  "'ssrs": 78,
#  "'ssis": 91,
#  "'ssa": 54,
#  "'mining": 56,
#  "'crm": 365,
#  "'technique": 445,
#  "'preferable": 128,
#  "'campaign": 727,
#  "'application": 4898,
#  "'processing": 469,
#  "'manipulation": 42,
#  "'tool": 943,
#  "'mdx": 12,
#  "'dataloads": 2,
#  "'rewriting": 6,
#  "'stored": 72,
#  "'procedure": 1373,
#  "'full": 3112,
#  "'understanding": 2230,
#  "'practice": 1466,
#  "'used": 507,
#  "'enterprise": 360,
#  "'warehouse": 227,
#  "'transformation": 120,
#  "'loading": 48,
#  "'olap": 11,
#  "'principal": 229,
#  "'multidimensional": 5,
#  "'star": 223,
#  "'schema": 11,
#  "'meet": 1300,
#  "'.net": 732,
#  "'coding": 135,
#  "'c": 1628,
#  "'visual": 225,
#  "'basic": 1407,
#  "'exposure": 539,
#  "'java": 680,
#  "'advantageous": 439,
#  "'developer": 2228,
#  "'rate": 759,
#  "'derivates": 3,
#  "'trade": 676,
#  "'multithreading": 21,
#  "'spring": 169,
#  "'jms/": 3,
#  "'core": 432,
#  "'java/": 4,
#  "'agile/": 4,
#  "'tdd****": 1,
#  "'****": 19252,
#  "'bonus": 1477,
#  "'benefitsmy": 4,
#  "'client": 11603,
#  "'investment": 545,
#  "'bank": 570,
#  "'city": 581,
#  "'london": 2565,
#  "'success": 984,
#  "'past": 151,
#  "'23": 92,
#  "'hire": 225,
#  "'become": 605,
#  "'part": 3011,
#  "'fixed": 297,
#  "'income": 230,
#  "'derivative": 41,
#  "'expected": 714,
#  "'programming": 419,
#  "'effort": 157,
#  "'person": 1267,
#  "'participate": 267,
#  "'peer": 55,
#  "'code": 377,
#  "'review": 1023,
#  "'one": 2681,
#  "'program": 337,
#  "'delivered": 280,
#  "'successfully": 258,
#  "'daily": 700,
#  "'basis": 1163,
#  "'new": 5383,
#  "'york": 87,
#  "'singapore": 23,
#  "'tddthe": 2,
#  "'5": 688,
#  "'javamultithreadingspringjms": 1,
#  "'mq": 11,
#  "'seriestdd/": 1,
#  "'bdd": 31,
#  "'agile": 402,
#  "'methodologymust": 1,
#  "'equitiespersonality": 1,
#  "'tdddemonstrate": 1,
#  "'commitment": 578,
#  "'organisation": 2445,
#  "'rolemaintain": 1,
#  "'professionalism": 73,
#  "'timesbuild": 1,
#  "'relationship": 1994,
#  "'colleaguesbe": 1,
#  "'efficient": 464,
#  "'effective": 1264,
#  "'fully": 659,
#  "'achieve": 854,
#  "'goalscontinuously": 1,
#  "'seek": 349,
#  "'improvement": 897,
#  "'higher": 176,
#  "'efficiency": 258,
#  "'effectivenessrecognise": 1,
#  "'importance": 103,
#  "'order": 1457,
#  "'clarity": 17,
#  "'workplace": 132,
#  "'workpossess": 1,
#  "'initiative": 794,
#  "'independently": 251,
#  "'confidence": 394,
#  "'take": 1813,
#  "'madea": 1,
#  "'methodical": 71,
#  "'approach": 1201,
#  "'enthusiasm": 279,
#  "'correctness": 2,
#  "'completeness": 12,
#  "'resultsdeadline": 1,
#  "'focusedhigh": 1,
#  "'energy": 532,
#  "'approachsystematic": 1,
#  "'structured": 239,
#  "'converse": 17,
#  "'communicate": 573,
#  "'teams.team": 1,
#  "'playerownership": 1,
#  "'workloadcan": 1,
#  "'think": 283,
#  "'beyond": 130,
#  "'impact": 300,
#  "'action": 511,
#  "'wider": 201,
#  "'environmentresilient": 1,
#  "'self": 483,
#  "'motivatedplease": 1,
#  "'forward": 1118,
#  "'cv": 3594,
#  "'eobiechefuargyllscott.com": 1,
#  "'call": 2328,
#  "'term": 1225,
#  "'12": 297,
#  "'month": 1428,
#  "'student": 458,
#  "'sims": 5,
#  "'provides": 462,
#  "'comprehensive": 342,
#  "'bespoke": 286,
#  "'support": 6432,
#  "'university": 299,
#  '’': 2038,
#  "'provision": 387,
#  "'active": 415,
#  "'wide": 740,
#  "'staff": 2901,
#  "'central": 628,
#  "'administration": 881,
#  "'faculty": 45,
#  "'requiring": 67,
#  "'well": 3474,
#  "'understand": 596,
#  "'develop": 2846,
#  "'oracle": 421,
#  "'software": 2801,
#  "'pl/sql": 47,
#  "'form": 551,
#  "'designing": 301,
#  "'developing": 1669,
#  "'situation": 169,
#  "'identify": 709,
#  "'build": 1246,
#  "'focused": 681,
#  "'pressure": 486,
#  "'priority": 247,
#  "'maintaining": 825,
#  "'flexibility": 259,
#  "'education": 944,
#  "'e.g": 446,
#  "'banner": 26,
#  "'issue": 1399,
#  "'grade": 209,
#  "'p": 145,
#  "'.a": 1,
#  "'informal": 157,
#  "'enquiry": 374,
#  "'may": 1322,
#  "'peter": 18,
#  "'bindon": 1,
#  "'group": 2296,
#  "'leader": 1256,
#  "'tel": 34,
#  "'email": 1877,
#  "'p.j.f.bindonleeds.ac.uk": 1,
#  "'ref": 378,
#  "'csiss****": 1,
#  "'recruiting": 1003,
#  "'hr": 1166,
#  "'manager": 8828,
#  "'leading": 3726,
#  "'multisite": 61,
#  "'truly": 225,
#  "'generalist": 89,
#  "'network": 1106,
#  "'unit": 556,
#  "'championing": 22,
#  "'delivering": 1099,
#  "'robust": 151,
#  "'advice": 599,
#  "'delivery": 1879,
#  "'agenda": 79,
#  "'change": 1262,
#  "'employee": 861,
#  "'involvement": 134,
#  "'engagement": 225,
#  "'adherence": 102,
#  "'completion": 357,
#  "'site": 1926,
#  "'plan": 1943,
#  "'main": 1063,
#  "'duty": 2007,
#  "'industrial": 370,
#  "'relation": 1131,
#  "'union": 34,
#  "'national": 812,
#  "'give": 452,
#  "'contract": 2143,
#  "'policy": 1381,
#  "'best": 1689,
#  "'advise": 190,
#  "'employment": 3370,
#  "'law": 389,
#  "'applicable": 156,
#  "'local": 987,
#  "'agreement": 172,
#  "'investigation": 183,
#  "'disciplinary": 109,
#  "'maternity": 163,
#  "'paternity": 4,
#  "'family": 494,
#  "'friendly": 582,
#  "'police": 66,
#  "'etc": 1038,
#  "'tu": 2,
#  "'forum": 34,
#  "'meeting": 1173,
#  "'wage": 46,
#  "'negs": 1,
#  "'fab": 5,
#  "'dispute": 40,
#  "'committee": 69,
#  "'workshop": 272,
#  "'rolled": 10,
#  "'capability": 387,
#  "'continuous": 407,
#  "'monitoring/improvement": 1,
#  "'absence": 197,
#  "'associated": 373,
#  "'sickness": 80,
#  "'preemployment": 20,
#  "'oh": 19,
#  "'coordination": 177,
#  "'producing": 333,
#  "'weekly/monthly": 9,
#  "'interrogating": 6,
#  "'sap": 307,
#  "'utilised": 23,
#  "'provide": 3322,
#  "'operational": 691,
#  "'involve": 645,
#  "'attendance": 95,
#  "'function": 769,
#  "'adhoc": 131,
#  "'tupe": 24,
#  "'pension": 1163,
#  "'maintained": 330,
#  "'problem": 956,
#  "'dealt": 67,
#  "'early": 234,
#  "'stage": 532,
#  "'cipd": 71,
#  "'studying": 29,
#  "'towards": 458,
#  "'extensive": 662,
#  "'human": 138,
#  "'resource": 823,
#  "'preferably": 503,
#  "'paced": 429,
#  "'date": 1262,
#  "'trustworthy": 20,
#  "'completely": 38,
#  "'confidential": 265,
#  "'influence": 237,
#  "'outcome": 187,
#  "'necessary": 881,
#  "'look": 471,
#  "'exercise": 48,
#  "'discretion": 33,
#  "'confidentiality": 81,
#  "'identifies": 27,
#  "'others": 456,
#  "'professionally": 132,
#  "'display": 164,
#  "'exceptional": 671,
#  "'drive": 1124,
#  "'tenacity": 42,
#  "'understands": 59,
#  "'goal": 381,
#  "'return": 824,
#  "'hard": 404,
#  "'receive": 1176,
#  "'car": 1283,
#  "'annual": 552,
#  "'25": 344,
#  "'depending": 437,
#  "'private": 778,
#  "'health": 1984,
#  "'care": 3530,
#  "'leave": 249,
#  "'contribution": 200,
#  "'scheme": 1397,
#  "'job": 7556,
#  "'originally": 2754,
#  "'posted": 2783,
#  "'www.totaljobs.com/jobseeking/hrprojectmanager_job****": 1,
#  "'social": 1128,
#  "'seeking": 1376,
#  "'child": 1104,
#  "'residential": 476,
#  "'setting": 581,
#  "'supportive": 231,
#  "'nurturing": 26,
#  "'young": 378,
#  "'profound": 6,
#  "'learning": 880,
#  "'difficulty": 89,
#  "'adhd": 5,
#  "'physical": 176,
#  "'disability": 512,
#  "'closeknit": 22,
#  "'four": 105,
#  "'house": 495,
#  "'assist": 1230,
#  "'everyday": 45,
#  "'personal": 1072,
#  "'treatment": 241,
#  "'pmld": 5,
#  "'two": 553,
#  "'shift": 886,
#  "'per": 2057,
#  "'weekend": 376,
#  "'late": 64,
#  "'motivated": 847,
#  "'committed": 777,
#  "'calm": 86,
#  "'nvq****": 14,
#  "'enhanced": 342,
#  "'crb": 402,
#  "'happy": 325,
#  "'apply": 4588,
#  "'field": 1176,
#  "'post": 1224,
#  "'please": 7022,
#  "'click": 398,
#  "'today": 596,
#  "'experienced": 2829,
#  "'consultant": 2219,
#  "'uk": 4637,
#  "'15": 93,
#  "'recruitment": 5093,
#  "'locum": 123,
#  "'permanent": 1815,
#  "'placement": 350,
#  "'graduate": 1210,
#  "'php": 285,
#  "'mysql": 156,
#  "'enfield": 21,
#  "'****k": 2230,
#  "'exciting": 1692,
#  "'recently": 198,
#  "'studied": 21,
#  "'internet": 156,
#  "'achieved": 322,
#  "'pas": 123,
#  "'mark": 209,
#  "'detailed": 426,
#  "'schedule": 351,
#  "'ready": 185,
#  "'make": 1294,
#  "'teaching": 820,
#  "'element": 208,
#  "'enthusiastic": 647,
#  "'recent": 444,
#  "'computer": 678,
#  "'science": 490,
#  "'sure": 239,
#  "'career": 3182,
#  "'foundation": 170,
#  "'taught": 17,
#  "'whole": 211,
#  "'world": 1048,
#  "'opened": 77,
#  "'onthejob": 10,
#  "'step": 381,
#  "'straight": 75,
#  "'learn": 518,
#  "'lamp": 48,
#  "'html": 366,
#  "'cs": 333,
#  "'javascript": 424,
#  "'opportunity": 8465,
#  "'soon": 210,
#  "'progress": 900,
#  "'junior": 482,
#  "'number": 1563,
#  "'online": 1575,
#  "'bluechip": 49,
#  "'asp.net": 615,
#  '.': 1184,
#  "'interest": 739,
#  "'get": 880,
#  "'touch": 299,
#  "'send": 1498,
#  "'directly": 584,
#  "'hannah.olcroftsenitor.com": 1,
#  "'keywords": 189,
#  "'senitor": 19,
#  "'associate": 367,
#  "'ltd": 858,
#  "'acting": 1149,
#  "'agency": 3511,
#  "'vacancy": 2227,
#  "'pr": 242,
#  "'account": 3161,
#  "'award": 604,
#  "'winning": 434,
#  "'offering": 823,
#  "'biggest": 92,
#  "'brand": 1375,
#  "'whilst": 804,
#  "'incorporated": 15,
#  "'innovative": 687,
#  "'pride": 270,
#  "'flagship": 53,
#  "'given": 505,
#  "'chance": 441,
#  "'nurture": 35,
#  "'diverse": 317,
#  "'presently": 17,
#  "'variety": 803,
#  "'telecom": 191,
#  "'asset": 366,
#  "'writing": 458,
#  "'suitable": 708,
#  "'consultancy": 1120,
#  "'offer": 2851,
#  "'mobile": 785,
#  "'hold": 639,
#  "'paneuropean": 9,
#  "'medium": 1277,
#  "'contact": 3382,
#  "'established": 1290,
#  "'press": 165,
#  "'comprehension": 5,
#  "'resultsfocused": 1,
#  "'state": 173,
#  "'mind": 112,
#  "'international": 1062,
#  "'demonstration": 56,
#  "'fantastic": 1407,
#  "'broaden": 24,
#  "'talentfilled": 1,
#  "'public": 615,
#  "'journalist": 17,
#  "'digital": 1138,
#  "'experiential": 22,
#  "'officer": 290,
#  "'www.totaljobs.com/jobseeking/praccountmanagerb2btechnology_job****": 1,
#  "'theatre": 125,
#  "'technician": 584,
#  "'costume": 3,
#  "'wardrobe": 2,
#  "'blut****full": 1,
#  "'temporary": 867,
#  "'30th": 5,
#  "'june": 31,
#  "'2013manchester": 1,
#  "'centresalary": 1,
#  "'pro": 167,
#  "'rataas": 1,
#  "'largest": 465,
#  "'college": 186,
#  "'europe": 367,
#  "'learner": 232,
#  "'manchester": 424,
#  "'mission": 91,
#  "'inclusive": 62,
#  "'curriculum": 181,
#  "'accessible": 70,
#  "'way.their": 1,
#  "'performing": 188,
#  "'art": 151,
#  "'objective": 635,
#  "'planned": 208,
#  "'adult": 274,
#  "'programmes.as": 1,
#  "'assessment": 714,
#  "'assisting": 469,
#  "'fe/he": 1,
#  "'class": 663,
#  "'examinations/assessments": 1,
#  "'events.as": 1,
#  "'directed": 107,
#  "'divisional": 58,
#  "'dynamic": 1047,
#  "'1st": 228,
#  "'area": 3348,
#  "'auditing": 88,
#  "'stock": 495,
#  "'utilise": 104,
#  "'equipment": 1081,
#  "'required.qualified": 1,
#  "'hnd/foundation": 1,
#  "'equivalent": 1066,
#  "'professional": 2981,
#  "'emphasis": 141,
#  "'costume/wardrobe": 1,
#  "'approachable": 79,
#  "'manner": 779,
#  "'communicative": 9,
#  "'monitor": 418,
#  "'prop": 4,
#  "'machine": 332,
#  "'required.closing": 1,
#  "'friday": 504,
#  "'8th": 19,
#  "'february": 418,
#  "'2013this": 1,
#  "'blue": 318,
#  "'octopus": 8,
#  "'operating": 624,
#  "'clicked": 8,
#  "'copy": 378,
#  "'via": 617,
#  "'compiler": 12,
#  "'gcc": 5,
#  "'llvm": 1,
#  "'cosy": 8,
#  "'frontend": 59,
#  "'parsing": 3,
#  "'optimisation": 113,
#  "'generation": 308,
#  "'backend": 37,
#  "'groundbreaking": 9,
#  "'semiconductor": 23,
#  "'forefront": 105,
#  "'latest": 427,
#  "'consumer": 334,
#  "'led": 134,
#  "'device": 254,
#  "'position": 4016,
#  "'engineer": 3416,
#  "'tasked": 100,
#  "'current": 1189,
#  "'next": 850,
#  "'graphic": 101,
#  "'hardware": 304,
#  "'gpus": 1,
#  "'plus": 1271,
#  "'following": 1832,
#  "'architecture": 388,
#  "'algorithm": 38,
#  "'multithreaded": 30,
#  "'and/or": 644,
#  "'parallel": 16,
#  "'computation": 13,
#  "'additionally": 88,
#  "'kernellevel": 1,
#  "'embedded": 185,
#  "'realtime": 40,
#  "'linux": 396,
#  "'wince": 5,
#  "'symbian": 2,
#  "'assembly": 216,
#  "'language": 462,
#  "'ic": 44,
#  "'eda": 10,
#  "'alex": 14,
#  "'fothergill": 2,
#  "'semicon": 1,
#  "'first": 1146,
#  "'dsp": 31,
#  "'charity": 281,
#  "'birmingham": 323,
#  "'fundraising": 142,
#  "'head": 1150,
#  "'finance": 1169,
#  "'grow": 557,
#  "'donor": 32,
#  "'corporate": 800,
#  "'devising": 23,
#  "'donation": 15,
#  "'posse": 642,
#  "'networking": 302,
#  "'negotiating": 150,
#  "'partnership": 376,
#  "'specification": 820,
#  "'langton": 2,
#  "'n****p": 2,
#  "'specialist": 1707,
#  "'convergence/mobile": 3,
#  "'working/m2m": 3,
#  "'telecommunication": 113,
#  "'****k****k": 85,
#  "'ote": 710,
#  "'benefit": 3232,
#  "'south": 849,
#  "'england": 268,
#  "'progressive": 227,
#  "'provider": 823,
#  "'focusing": 136,
#  "'multinational": 121,
#  "'exceed": 353,
#  "'realistic": 98,
#  "'target": 1572,
#  "'taking": 571,
#  "'opening": 280,
#  "'targeted": 117,
#  "'overlay": 2,
#  "'capacity": 270,
#  "'liaising": 529,
#  "'facing": 353,
#  "'portfolio": 778,
#  "'inspire": 146,
#  "'respect": 257,
#  "'everyone": 126,
#  "'externally": 110,
#  "'example": 216,
#  "'3": 943,
#  "'frontline": 17,
#  "'gained": 317,
#  "'clear": 469,
#  "'appreciation": 109,
#  "'real": 617,
#  "'approaching": 18,
#  "'show": 218,
#  "'enrich": 5,
#  "'selfmotivation": 36,
#  "'literacy": 154,
#  "'driver": 380,
#  "'licence": 504,
#  "'determination": 121,
#  "'limit": 64,
#  "'reward": 467,
#  "'prospect": 406,
#  "'expect": 324,
#  "'generous": 313,
#  "'base": 753,
#  "'salary": 3882,
#  "'uncapped": 327,
#  "'package": 1944,
#  "'advising": 165,
#  ...}

# %% [markdown]
# Selecting 10 most common words

# %%
from operator import itemgetter
topword = sorted(resultword.items(), key=itemgetter(1), reverse=True)[:10]
topword
# Out:
# [("'", 1553487),
#  (',', 1545339),
#  ("'****", 19252),
#  ("'experience", 17553),
#  ("'role", 12758),
#  ("'team", 12349),
#  ("'work", 12106),
#  ("'client", 11603),
#  ("'business", 11362),
#  ("'service", 10220)]

# %% [markdown]
# # Part B

# %%
from pandas import Series, DataFrame
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
min_data = rev_data['SalaryNormalized'].astype(int).quantile(.75)
rev_data['Salary_rank_75'] = rev_data['SalaryNormalized'].astype(int) >= min_data
rev_data['Salary_rank_not_75']= rev_data['SalaryNormalized'].astype(int) <= min_data
rev_data = rev_data[['FullDescription','Salary_rank_75','Salary_rank_not_75']]
rev_train = rev_data[:9000]
rev_test = rev_data[9001:]

# %% [markdown]
# # B1

# %% [markdown]
# Create a classification model with all words and the bag-of-words approach. How accurate is the model (show the confusion matrix)?

# %% [markdown]
# ## Bag of Words

# %% [markdown]
# Calculate frequency of each word occurence and use multinomial Naive Bayes to train the model

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(rev_train['FullDescription'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB().fit(X_train_tfidf,rev_train['Salary_rank_75'])

# %%
X_test_counts = count_vect.transform(rev_test['FullDescription'])
X_new_tfidf = tfidf_transformer.transform(X_test_counts)
predicted = classifier.predict(X_new_tfidf)
rev_test['predicted_output'] = predicted
# Out:
# C:\Users\Monika\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pd.crosstab(rev_test['Salary_rank_75'], rev_test['predicted_output'])
# Out:
# predicted_output  False  True
# Salary_rank_75
# False               756      2
# True                237      4

# %% [markdown]
# This shows an accuracy of 76%

# %% [markdown]
# ## All words

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from nltk.tokenize import word_tokenize

# %%
### All words
labels = rev_data.FullDescription.apply(word_tokenize).to_frame()
labels['category'] = rev_data['Salary_rank_75']

# %% [markdown]
# Create document with description and corresponding category together in a list

# %%
d = [(list(labels['FullDescription'].iloc[i]),labels['category'].iloc[i]) for i in range(0,len(labels))]
random.shuffle(d)

# %% [markdown]
# Calculate word features based on their frequency distance and select top 1000 words

# %%
from itertools import chain
word_features = nltk.FreqDist(chain(*[i for i,j in d]))
word_features_rev = list(word_features)[:1000]
numtrain = int(len(d) * 90 / 100)

# %%
train_set = [({i:(i in tokens) for i in word_features_rev}, tag) for tokens,tag in d[:numtrain]]

# %%
test_set = [({i:(i in tokens) for i in word_features_rev}, tag) for tokens,tag in d[numtrain:]]

# %% [markdown]
# Run binomial Naive Bayes to train the model

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.742

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#                classroom = True            False : True   =     15.4 : 1.0
#                     Park = True            False : True   =     11.7 : 1.0
#                 evenings = True            False : True   =     11.3 : 1.0
#                  teacher = True            False : True   =      8.6 : 1.0
#                   Subsea = True             True : False  =      8.5 : 1.0

# %%
test_result = []
gold_result = []
for i in range(len(test_set)):
    test_result.append(classifier.classify(test_set[i][0]))
    gold_result.append(test_set[i][1])
cm = nltk.ConfusionMatrix(gold_result, test_result)
print(cm.pretty_format(sort_by_count=True, show_percents=True, truncate=9))
# Out:
#       |      F        |
#       |      a      T |
#       |      l      r |
#       |      s      u |
#       |      e      e |
# ------+---------------+
# False | <56.7%> 15.7% |
#  True |  10.1% <17.5%>|
# ------+---------------+
# (row = reference; col = test)

# %% [markdown]
# ## B2

# %% [markdown]
# Speculate before running the following analysis whether lemmatization would help improve the accuracy of classification. Now create a classification model after lemmatization. Did the classification accuracy increase relative to B1? Comment on your speculation versus the actual results you obtained.

# %% [markdown]
# Lemmatization should help improve accuracy of classifier since it groups all words together on basis of their root words. Hence a lot of similar words should be associated with each other making it easier to classify them in test dataset

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# Create a function to convert descriptions to work tokens and then lemmatize them

# %%
corpus=[]
def tokenizelem(item):
    text = word_tokenize(item.lower())
    lem = list(map(lemmatizer.lemmatize, text))
    corpus.append(lem)

rev_data["FullDescription"].apply(tokenizelem)
rev_data["Description_corpus"]=corpus
rev_data["Description_corpus"]=rev_data["Description_corpus"].astype(str)

# %%
rev_train = rev_data[:9000]
rev_test = rev_data[9001:]

# %% [markdown]
# Run a multinomial naive bayes on word tokens obtained after lemmatization

# %%
X_train_counts_lem = count_vect.fit_transform(rev_train['Description_corpus'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf_lem = tfidf_transformer.fit_transform(X_train_counts_lem)
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB().fit(X_train_tfidf_lem,rev_train['Salary_rank_75'])

# %%
X_test_counts_lem = count_vect.transform(rev_test['Description_corpus'])
X_new_tfidf_lem = tfidf_transformer.transform(X_test_counts_lem)
predicted = classifier.predict(X_new_tfidf_lem)
rev_test['predicted_output'] = predicted
# Out:
# C:\Users\Monika\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pd.crosstab(rev_test['Salary_rank_75'], rev_test['predicted_output'])
# Out:
# predicted_output  False  True
# Salary_rank_75
# False               757      1
# True                236      5

# %% [markdown]
# The accuracy is 76.2% here. This shows lemmatization has not significantly improved accuracy here

# %% [markdown]
# ## B3

# %% [markdown]
# Now speculate whether stopwords removal from the original data would help increase the accuracy of the model. Take out the stopwords (but do not lemmatize), build a classification model and check the accuracy, and compare with that in B1 & B2.

# %% [markdown]
# If lemmatization did not improve accuracy, we believe even stopwords won't be useful for improving accuracy because the word associations would still remain the same

# %%
from nltk.corpus import stopwords
import string

# %% [markdown]
# Create function to tokenize word descriptions and remove all stopwords

# %%
corpus=[]
def tokenizestop(item):
    stop = stopwords.words('english') + list(string.punctuation)
    text = [i for i in word_tokenize(item.lower()) if i not in stop]
    corpus.append(text)

rev_data["FullDescription"].apply(tokenizestop)
rev_data["Description_corpus_stop"]=corpus
rev_data["Description_corpus_stop"]=rev_data["Description_corpus_stop"].astype(str)

# %%
rev_train = rev_data[:9000]
rev_test = rev_data[9001:]

# %%
X_train_counts_stop = count_vect.fit_transform(rev_train['Description_corpus_stop'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf_stop = tfidf_transformer.fit_transform(X_train_counts_stop)
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB().fit(X_train_tfidf_stop,rev_train['Salary_rank_75'])

# %%
X_test_counts_stop = count_vect.transform(rev_test['Description_corpus_stop'])
X_test_counts_stop = tfidf_transformer.transform(X_test_counts_stop)
predicted = classifier.predict(X_test_counts_stop)
rev_test['predicted_output'] = predicted
# Out:
# C:\Users\Monika\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pd.crosstab(rev_test['Salary_rank_75'], rev_test['predicted_output'])
# Out:
# predicted_output  False  True
# Salary_rank_75
# False               756      2
# True                232      9

# %% [markdown]
# The accuracy has increased to 76.5%. Still its approximately the same. Here lemmatization and removal of stopwords has not lead to improved accuracy

# %%
from operator import itemgetter
N = 10
vocabulary = np.array([t for t, i in sorted(count_vect.vocabulary_.items(), key=itemgetter(1))])

topN = np.argsort(classifier.coef_[0])[-10:]
vocabulary[topN]
# Out:
# array(['client', 'within', 'role', 'manager', 'development', 'team',
#        'project', 'management', 'experience', 'business'],
#       dtype='<U94')

# %% [markdown]
# **These are the top 10 words for highest earners**

# %%
corpus2=[]
def tokenizestop(item):
    stop = stopwords.words('english') + list(string.punctuation)
    text = [i for i in word_tokenize(item.lower()) if i not in stop]
    corpus2.append(text)

rev_data["FullDescription"].apply(tokenizestop)
rev_data["Description_corpus_stop2"]=corpus2
rev_data["Description_corpus_stop2"]=rev_data["Description_corpus_stop2"].astype(str)

# %%
rev_train = rev_data[:9000]
rev_test = rev_data[9001:]

# %%
X_train_counts_stop = count_vect.fit_transform(rev_train['Description_corpus_stop2'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf_stop = tfidf_transformer.fit_transform(X_train_counts_stop)
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB().fit(X_train_tfidf_stop,rev_train['Salary_rank_not_75'])

# %%
X_test_counts_stop = count_vect.transform(rev_test['Description_corpus_stop2'])
X_test_counts_stop = tfidf_transformer.transform(X_test_counts_stop)
predicted = classifier.predict(X_test_counts_stop)
rev_test['predicted_output'] = predicted
# Out:
# C:\Users\Monika\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
from operator import itemgetter
N = 10
vocabulary = np.array([t for t, i in sorted(count_vect.vocabulary_.items(), key=itemgetter(1))])

topN = np.argsort(classifier.coef_[0])[-10:]
vocabulary[topN]
# Out:
# array(['within', 'working', 'manager', 'skills', 'business', 'team',
#        'role', 'work', 'experience', 'sales'],
#       dtype='<U94')

# %% [markdown]
# **These are the top 10 words for lowest earners**

# %% [markdown]
# ## B4

# %%
count_vect = CountVectorizer(ngram_range=(1,2))
X_train_counts = count_vect.fit_transform(rev_train['FullDescription'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB().fit(X_train_tfidf,rev_train['Salary_rank_75'])

# %%
X_test_counts = count_vect.transform(rev_test['FullDescription'])
X_new_tfidf = tfidf_transformer.transform(X_test_counts)
predicted = classifier.predict(X_new_tfidf)
rev_test['predicted_output'] = predicted
# Out:
# C:\Users\Monika\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pd.crosstab(rev_test['Salary_rank_75'], rev_test['predicted_output'])
# Out:
# predicted_output  False
# Salary_rank_75
# False               758
# True                241

# %% [markdown]
# **The accuracy decreases to 75.87% when we include the bigrams. Now, the decrease in accuracy is just 0.83% which isn't much, but we hoped that the accuracy should have increased when we included the bigrams (before running our script)**
